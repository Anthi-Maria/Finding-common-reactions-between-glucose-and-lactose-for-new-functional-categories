# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")

# %%
df= pd.read_csv('one feasible value at zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value at zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions one feasible value original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions one feasible value original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions one feasible value original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions one feasible value original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions one feasible value original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions one feasible value original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions one feasible value original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions one feasible value original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions one feasible value original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions one feasible value original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions one feasible value original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions one feasible value original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions one feasible value original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions one feasible value original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions one feasible value original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions one feasible value original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions one feasible value original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions one feasible value original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions one feasible value original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions one feasible value original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions one feasible value original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions one feasible value original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions one feasible value at zero original-one feasible value at zero lactose")

# %%
len(D15)
# Out:
# 64

# %%
df= pd.read_csv('diff_saturated only above zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions saturated only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions saturated only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions saturated only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions saturated only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions saturated only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions saturated only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions saturated only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions saturated only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions saturated only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions saturated only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions saturated only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions saturated only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions saturated only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions saturated only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions saturated only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions saturated only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions saturated only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions saturated only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions saturated only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions saturated only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions saturated only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions saturated only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions saturated only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('flat only above zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat only above zero zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions flat only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions flat only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions flat only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions flat only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions flat only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions flat only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions flat only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions flat only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions flat only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions flat only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions flat only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions flat only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions flat only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions flat only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions flat only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions flat only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions flat only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions flat only above zero-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions flat only above zero-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions flat only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions flat only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions flat only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions flat only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('flat only below zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat only below zero zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions flat only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions flat only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions flat only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions flat only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions flat only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions flat only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions flat only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions flat only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions flat only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions flat only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions flat only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions flat only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions flat only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions flat only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions flat only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions flat only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions flat only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions flat only below zero-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions flat only below zero-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions flat only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions flat only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions flat only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions flat only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('flat both positive and negative.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat both positive and negative original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat both positive and negative original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat both positive and negative original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat both positive and negative original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat both positive and negative original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat both positive and negative original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat both positive and negative original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat both positive and negative original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat both positive and negative original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions flat both positive and negative original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions flat both positive and negative original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions flat both positive and negative original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions flat both positive and negative original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions flat both positive and negative original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions flat both positive and negative original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions flat both positive and negative original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions flat both positive and negative original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions flat both positive and negative original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions flat both positive and negative original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions flat both positive and negative original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions flat both positive and negative original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions flat both positive and negative original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions flat both positive and negative original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions flat both positive and negative original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions flat both positive and negative original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions flat both positive and negative original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions flat both positive and negative original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions flat both positive and negative original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions flat both positive and negative original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions flat both positive and negative original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions flat both positive and negative original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions flat both positive and negative original-one feasible value at zero lactose")

# %%
df= pd.read_csv('diff_saturated only below zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions saturated only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions saturated only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions saturated only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions saturated only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions saturated only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions saturated only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions saturated only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions saturated only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions saturated only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions saturated only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions saturated only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions saturated only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions saturated only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions saturated only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions saturated only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions saturated only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions saturated only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions saturated only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions saturated only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions saturated only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions saturated only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions saturated only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions saturated only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('Ushaped_reactions only below zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions Ushaped only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions Ushaped only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions Ushaped only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions Ushaped only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions Ushaped only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions Ushaped only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions Ushaped only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions Ushaped only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions Ushaped only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions Ushaped only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions Ushaped only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions Ushaped only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions Ushaped only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions Ushaped only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions Ushaped only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions Ushaped only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions Ushaped only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions Ushaped only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions Ushaped only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions Ushaped only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions Ushaped only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions Ushaped only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions Ushaped only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('diff_saturated both positive and negative.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated both positive and negative original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated both positive and negative original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated both positive and negative original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated both positive and negative original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated both positive and negative original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated both positive and negative original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated both positive and negative original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated both positive and negative original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated both positive and negative original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions saturated both positive and negative original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions saturated both positive and negative original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions saturated both positive and negative original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions saturated both positive and negative original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions saturated both positive and negative original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions saturated both positive and negative original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions saturated both positive and negative original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions saturated both positive and negative original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions saturated both positive and negative original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions saturated both positive and negative original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions saturated both positive and negative original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions saturated both positive and negative original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions saturated both positive and negative original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions saturated both positive and negative original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions saturated both positive and negative original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions saturated both positive and negative original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions saturated both positive and negative original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions saturated both positive and negative original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions saturated both positive and negative original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions saturated both positive and negative original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions saturated both positive and negative original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions saturated both positive and negative original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions saturated both positive and negative original-one feasible value at zero lactose")

# %%
df= pd.read_csv('Ushaped both positive and negative.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped both positive and negative original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped both positive and negative original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped both positive and negative original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped both positive and negative original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped both positive and negative original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped both positive and negative original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped both positive and negative original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped both positive and negative original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped both positive and negative original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions Ushaped both positive and negative original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions Ushaped both positive and negative original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions Ushaped both positive and negative original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions Ushaped both positive and negative original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions Ushaped both positive and negative original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions Ushaped both positive and negative original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions Ushaped both positive and negative original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions Ushaped both positive and negative original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions Ushaped both positive and negative original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions Ushaped both positive and negative original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions Ushaped both positive and negative original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions Ushaped both positive and negative original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions Ushaped both positive and negative original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions Ushaped both positive and negative original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions Ushaped both positive and negative original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions Ushaped both positive and negative original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions Ushaped both positive and negative original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions Ushaped both positive and negative original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions Ushaped both positive and negative original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions Ushaped both positive and negative original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions Ushaped both positive and negative original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions Ushaped both positive and negative original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions Ushaped both positive and negative original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing and stable only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing and stable only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing and stable only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing and stable only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing and stable only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing and stable only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing and stable only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing and stable only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing and stable only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing and stable only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing and stable only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing and stable only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing and stable only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing and stable only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing and stable only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing and stable only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing and stable only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing and stable only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing and stable only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing and stable only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing and stable only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing and stable only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing and stable only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing and stable only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing and stable only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing and stable only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing and stable only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing and stable only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing and stable only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing and stable only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing and stable only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing and stable only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing and stable only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only above zero reactions original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only above zero reactions original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only above zero reactions original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only above zero reactions original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only above zero reactions original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only above zero reactions original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only above zero reactions original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only above zero reactions original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only above zero reactions original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only above zero reactions original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only above zero reactions original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only above zero reactions original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only above zero reactions original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only above zero reactions original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only above zero reactions original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only above zero reactions original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only above zero reactions original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only above zero reactions original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only above zero reactions original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only above zero reactions original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only above zero reactions original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only above zero reactions original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only above zero reactions original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only above zero reactions original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only above zero reactions original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only above zero reactions original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only above zero reactions original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only above zero reactions original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only above zero reactions original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only above zero reactions original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only above zero reactions original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing only above zero reactions original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and stable only below zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and stable only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and stable only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and stable only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and stable only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and stable only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and stable only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and stable only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and stable only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and stable only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and stable only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and stable only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and stable only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and stable only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and stable only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and stable only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and stable only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and stable only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and stable only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and stable only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and stable only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and stable only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and stable only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and stable only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and stable only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and stable only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and stable only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and stable only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and stable only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and stable only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and stable only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and stable only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and stable only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing only below zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('monotonically increasing only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically increasing only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically increasing only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically increasing only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically increasing only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically increasing only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically increasing only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically increasing only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically increasing only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically increasing only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically increasing only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically increasing only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically increasing only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically increasing only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically increasing only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically increasing only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically increasing only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically increasing only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically increasing only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically increasing only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically increasing only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically increasing only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically increasing only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions monotonically increasing only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing and stable only below zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing and stable only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing and stable only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing and stable only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing and stable only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing and stable only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing and stable only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing and stable only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing and stable only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing and stable only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing and stable only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing and stable only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing and stable only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing and stable only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing and stable only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing and stable only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing and stable only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing and stable only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing and stable only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing and stable only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing and stable only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing and stable only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing and stable only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing and stable only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing and stable only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing and stable only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing and stable only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing and stable only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing and stable only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing and stable only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing and stable only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing and stable only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing and stable only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing only below zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero and increasing only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero and increasing only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero and increasing only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero and increasing only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero and increasing only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero and increasing only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero and increasing only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero and increasing only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero and increasing only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero and increasing only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero and increasing only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero and increasing only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero and increasing only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero and increasing only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing only below zero and increasing only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing only below zero and decreasing only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing only below zero and decreasing only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing only below zero and decreasing only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing only below zero and decreasing only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing only below zero and decreasing only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing only below zero and decreasing only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing only below zero and decreasing only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing only below zero and decreasing only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing only below zero and decreasing only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing only below zero and decreasing only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing only below zero and decreasing only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing only below zero and decreasing only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing only below zero and decreasing only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing only below zero and decreasing only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing only below zero and decreasing only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and stable only below zero and increasing only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions stable only below zero and increasing only above zero reactions original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero and stable only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero and stable only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero and stable only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero and stable only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero and stable only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero and stable only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero and stable only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero and stable only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero and stable only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero and stable only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero and stable only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero and stable only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero and stable only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero and stable only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing only below zero and stable only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing and stable only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing and stable only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing and stable only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing and stable only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing and stable only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing and stable only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and decreasing and stable only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing and stable only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing and stable only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing and stable only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing and stable only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing and stable only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing and stable only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and decreasing and stable only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing and stable both positive and negative original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing and stable both positive and negative original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing and stable both positive and negative original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing and stable both positive and negative original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing and stable both positive and negative original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing and stable both positive and negative original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing and stable both positive and negative original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing and stable both positive and negative original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing and stable both positive and negative original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing and stable both positive and negative original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing and stable both positive and negative original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing and stable both positive and negative original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing and stable both positive and negative original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing and stable both positive and negative original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing and stable both positive and negative original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing and stable both positive and negative original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing and stable both positive and negative original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing and stable both positive and negative original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and decreasing only above zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only above zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only above zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only above zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only above zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only above zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only above zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only above zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only above zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only above zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing only above zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing only above zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing only above zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing only above zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing only above zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing only above zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing only above zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing only above zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing only above zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing only above zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing only above zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing only above zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing only above zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing only above zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing only above zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing only above zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing only above zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing only above zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing only above zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing only above zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing only above zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing only above zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and decreasing only above zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and decreasing only below zero.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only below zero original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only below zero original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only below zero original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only below zero original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only below zero original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only below zero original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only below zero original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only below zero original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only below zero original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing only below zero original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing only below zero original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing only below zero original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing only below zero original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing only below zero original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing only below zero original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing only below zero original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing only below zero original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing only below zero original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing only below zero original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing only below zero original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing only below zero original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing only below zero original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing only below zero original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing only below zero original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing only below zero original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing only below zero original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing only below zero original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing only below zero original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing only below zero original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing only below zero original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing only below zero original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and decreasing only below zero original-one feasible value at zero lactose")

# %%
df= pd.read_csv('increasing and decreasing both positive and negative.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero lactose.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero lactose.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative lactose.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero lactose.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative lactose.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative lactose.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions lactose.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero lactose.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero lactose.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('stable below zero and decreasing and stable above zero.csv')
ag= df31.iloc[:, 1]

df32= pd.read_csv('one feasible value at zero reactions lactose.csv')
ah= df.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))
intersect32 = pd.Series(np.intersect1d(b, ah))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing both positive and negative original-one feasible value NOT at zero lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing both positive and negative original-flat only above zero lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing both positive and negative original-flat only below zero lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing both positive and negative original-flat both positive and negative lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing both positive and negative original-saturated only below zero lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing both positive and negative original-Ushaped_reactions only below zero lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing both positive and negative original-saturated both positive and negative lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing both positive and negative original-Ushaped both positive and negative lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing and stable only above zero reactions lactose")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing only above zero reactions lactose")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and stable only below zero reactions lactose")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing only below zero reactions lactose")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing both positive and negative original-monotonically increasing and stable only above zero reactions lactose")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing both positive and negative original-monotonically increasing only above zero reactions lactose")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing and stable only below zero reactions lactose")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing only below zero reactions lactose")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing only below zero and increasing only above zero reactions lactose")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing only below zero and decreasing only above zero reactions lactose")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and stable only below zero and increasing only above zero reactions lactose")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing both positive and negative original-stable only below zero and increasing only above zero reactions lactose")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing only below zero and increasing and stable only above zero reactions lactose")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing only below zero and stable only above zero reactions lactose")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and decreasing and stable only above zero reactions lactose")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and decreasing and stable only below zero reactions lactose")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing and stable both positive and negative reactions lactose")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing orand decreasing or both and stable below zero and decreasing above zero lactose")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing both positive and negative original-decreasing below zero and increasing or decreasing or both and stable above zero lactose")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and decreasing only above zero lactose")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and decreasing only below zero lactose")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing both positive and negative original-increasing and decreasing both positive and negative lactose")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing both positive and negative original-stable below zero and decreasing and stable above zero lactose")
D31= pd.DataFrame(intersect32, columns=['Reaction names'])
D31.to_csv("Common reactions increasing and decreasing both positive and negative original-one feasible value at zero lactose")

# %%
df= pd.read_csv('one feasible value NOT at zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value NOT at zero reactions lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value NOT at zero reactions lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value NOT at zero reactions lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value NOT at zero reactions lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value NOT at zero reactions lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value NOT at zero reactions lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value NOT at zero reactions lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value NOT at zero reactions lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions one feasible value NOT at zero reactions lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions one feasible value NOT at zero reactions lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions one feasible value NOT at zero reactions lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions one feasible value NOT at zero reactions lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions one feasible value NOT at zero reactions lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions one feasible value NOT at zero reactions lactose-one feasible value at zero original")

# %%
df= pd.read_csv('one feasible value at zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value at zero reactions lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value at zero reactions lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value at zero reactions lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value at zero reactions lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value at zero reactions lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value at zero reactions lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value at zero reactions lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value at zero reactions lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions one feasible value at zero reactions lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions one feasible value at zero reactions lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions one feasible value at zero reactions lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions one feasible value at zero reactions lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions one feasible value at zero reactions lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions one feasible value at zero reactions lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions one feasible value at zero reactions lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions one feasible value at zero reactions lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions one feasible value at zero reactions lactose-one feasible value at zero original")

# %%
df= pd.read_csv('flat only above zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions flat only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions flat only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions flat only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions flat only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions flat only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions flat only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions flat only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions flat only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions flat only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions flat only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions flat only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions flat only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions flat only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions flat only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions flat only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions flat only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions flat only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions flat only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions flat only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions flat only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions flat only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions flat only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('flat only below zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions flat only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions flat only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions flat only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions flat only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions flat only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions flat only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions flat only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions flat only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions flat only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions flat only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions flat only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions flat only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions flat only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions flat only below zerolactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions flat only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions flat only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions flat only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions flat only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions flat only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions flat only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions flat only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions flat only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('flat both positive and negative lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat both positive and negative lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat both positive and negative lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat both positive and negative lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat both positive and negative lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat both positive and negative lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat both positive and negative lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat both positive and negative lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat both positive and negative lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat both positive and negative lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions flat both positive and negative lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions flat both positive and negative lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions flat both positive and negative lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions flat both positive and negative lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions flat both positive and negative lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions flat both positive and negative lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions flat both positive and negative lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions flat both positive and negative lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions flat both positive and negative lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions flat both positive and negative lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions flat both positive and negative lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions flat both positive and negative lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions flat both positive and negative lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions flat both positive and negative lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions flat both positive and negative lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions flat both positive and negative lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions flat both positive and negative lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions flat both positive and negative lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions flat both positive and negative lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions flat both positive and negative lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions flat both positive and negative lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions flat both positive and negative lactose-one feasible value at zero original")

# %%
df= pd.read_csv('diff_saturated only below zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions diff_saturated only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions diff_saturated only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions diff_saturated only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions diff_saturated only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions diff_saturated only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions diff_saturated only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions diff_saturated only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions diff_saturated only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions diff_saturated only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions diff_saturated only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions diff_saturated only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions diff_saturated only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions diff_saturated only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions diff_saturated only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions diff_saturated only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions diff_saturated only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions diff_saturated only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions diff_saturated only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions diff_saturated only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions diff_saturated only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions diff_saturated only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions diff_saturated only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions diff_saturated only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions diff_saturated only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions diff_saturated only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions diff_saturated only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions diff_saturated only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions diff_saturated only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions diff_saturated only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions diff_saturated only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions diff_saturated only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('Ushaped_reactions only below zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped_reactions only below zero zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped_reactions only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped_reactions only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped_reactions only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped_reactions only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped_reactions only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped_reactions only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped_reactions only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions Ushaped_reactions only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions Ushaped_reactions only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions Ushaped_reactions only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions Ushaped_reactions only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions Ushaped_reactions only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions Ushaped_reactions only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('diff_saturated both positive and negative lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated both positive and negative lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated both positive and negative lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated both positive and negative lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated both positive and negative lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated both positive and negative lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated both positive and negative lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated both positive and negative lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated both positive and negative lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated both positive and negative lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions saturated both positive and negative lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions saturated both positive and negative lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions saturated both positive and negative lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions saturated both positive and negative lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions saturated both positive and negative lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions saturated both positive and negative lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions saturated both positive and negative lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions saturated both positive and negative lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions saturated both positive and negative lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions saturated both positive and negative lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions saturated both positive and negative lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions saturated both positive and negative lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions saturated both positive and negative lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions saturated both positive and negative lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions saturated both positive and negative lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions saturated both positive and negative lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions saturated both positive and negative lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions saturated both positive and negative lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions saturated both positive and negative lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions saturated both positive and negative lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions saturated both positive and negative lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions saturated both positive and negative lactose-one feasible value at zero original")

# %%
df= pd.read_csv('Ushaped both positive and negative lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped both positive and negative lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped both positive and negative lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped both positive and negative lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped both positive and negative lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped both positive and negative lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped both positive and negative lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped both positive and negative lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped both positive and negative lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions Ushaped both positive and negative lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions Ushaped both positive and negative lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions Ushaped both positive and negative lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions Ushaped both positive and negative lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions Ushaped both positive and negative lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions Ushaped both positive and negative lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions Ushaped both positive and negative lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions Ushaped both positive and negative lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions Ushaped both positive and negative lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically decreasing and stable only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically decreasing and stable only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically decreasing only only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically decreasing only only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically decreasing only only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically decreasing only only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically decreasing only only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically decreasing only only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically decreasing only only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically increasing and stable only below zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically increasing and stable only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically increasing and stable only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically increasing and stable only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically increasing and stable only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically increasing and stable only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically increasing and stable only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically increasing only only below zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically increasing only only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically increasing only only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically increasing only only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically increasing only only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically increasing only only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically increasing only only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically increasing and stable only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically increasing and stable only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically increasing and stable only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically increasing and stable only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically increasing and stable only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically increasing and stable only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically increasing and stable only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically increasing only only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically increasing only only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically increasing only only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically increasing only only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically increasing only only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically increasing only only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically increasing only only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically decreasing and stable only below zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically decreasing and stable only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('monotonically decreasing only only below zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions monotonically decreasing only only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions monotonically decreasing only only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions monotonically decreasing only only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions monotonically decreasing only only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions monotonically decreasing only only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions monotonically decreasing only only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('decreasing only below zero and increasing only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero and increasing only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing only below zero and decreasing only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing only below zero and decreasing only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('stable only below zero and increasing only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions stable only below zero and increasing only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions stable only below zero and increasing only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions stable only below zero and increasing only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions stable only below zero and increasing only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions stable only below zero and increasing only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions stable only below zero and increasing only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions stable only below zero and increasing only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions stable only below zero and increasing only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions stable only below zero and increasing only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions stable only below zero and increasing only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions stable only below zero and increasing only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions stable only below zero and increasing only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions stable only below zero and increasing only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions stable only below zero and increasing only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero and increasing and stable only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('decreasing only below zero and stable only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing only below zero and stable only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing and decreasing and stable only above zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing and stable only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing and decreasing and stable only below zero reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('decreasing and stable both positive and negative reactions lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing and stable both positive and negative lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing and stable both positive and negative lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing and stable both positive and negative lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing and stable both positive and negative lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing and stable both positive and negative lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing and stable both positive and negative lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing and stable both positive and negative lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing and stable both positive and negative lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing and stable both positive and negative lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing and stable both positive and negative lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing and stable both positive and negative lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing and stable both positive and negative lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing and stable only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing orand decreasing or both and stable below zero and decreasing above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions decreasing below zero and increasing or decreasing or both and stable above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing and decreasing only above zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing only above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing only above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing only above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing only above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing only above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing only above zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing and decreasing only below zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only below zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only below zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only below zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only below zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only below zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only below zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only below zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only below zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing only below zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing only below zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing only below zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing only below zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing only below zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing only below zero lactose-one feasible value at zero original")

# %%
df= pd.read_csv('increasing and decreasing both positive and negative lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing both positive and negative lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing both positive and negative lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing both positive and negative lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing both positive and negative lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing both positive and negative lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing both positive and negative lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing both positive and negative lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing both positive and negative lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions increasing and decreasing both positive and negative lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions increasing and decreasing both positive and negative lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions increasing and decreasing both positive and negative lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions increasing and decreasing both positive and negative lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions increasing and decreasing both positive and negative lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions increasing and decreasing both positive and negative lactose-one feasible value at zero original")

# %%
df= pd.read_csv('stable below zero and decreasing and stable above zero lactose.csv')
b= df.iloc[:, 1]

df1= pd.read_csv('diff_saturated only above zero.csv')
c= df1.iloc[:, 1]

df2= pd.read_csv('flat only above zero.csv')
d= df2.iloc[:, 1]

df3= pd.read_csv('flat only below zero.csv')
e= df3.iloc[:, 1]

df4= pd.read_csv('flat both positive and negative.csv')
f= df4.iloc[:, 1]

df5= pd.read_csv('diff_saturated only below zero.csv')
g= df5.iloc[:, 1]

df6= pd.read_csv('Ushaped_reactions only below zero.csv')
h= df6.iloc[:, 1]

df7= pd.read_csv('diff_saturated both positive and negative.csv')
i= df7.iloc[:, 1]

df8= pd.read_csv('Ushaped both positive and negative.csv')
j= df8.iloc[:, 1]

df9= pd.read_csv('decreasing and stable only above zero reactions.csv')
k= df9.iloc[:, 1]

df10= pd.read_csv('decreasing only above zero reactions.csv')
l= df10.iloc[:, 1]

df11= pd.read_csv('increasing and stable only below zero reactions.csv')
m= df11.iloc[:, 1]

df12= pd.read_csv('increasing only below zero reactions.csv')
n= df12.iloc[:, 1]

df13= pd.read_csv('monotonically increasing and stable only above zero reactions.csv')
o= df13.iloc[:, 1]

df14= pd.read_csv('monotonically increasing only above zero reactions.csv')
p= df14.iloc[:, 1]

df15= pd.read_csv('decreasing and stable only below zero reactions.csv')
q= df15.iloc[:, 1]

df16= pd.read_csv('decreasing only below zero reactions.csv')
r= df16.iloc[:, 1]

df17= pd.read_csv('decreasing only below zero and increasing only above zero reactions.csv')
s= df17.iloc[:, 1]

df18= pd.read_csv('increasing only below zero and decreasing only above zero reactions.csv')
t= df18.iloc[:, 1]

df19= pd.read_csv('increasing and stable only below zero and increasing only above zero reactions.csv')
u= df19.iloc[:, 1]

df20= pd.read_csv('stable only below zero and increasing only above zero reactions.csv')
v= df20.iloc[:, 1]

df21= pd.read_csv('decreasing only below zero and increasing and stable only above zero reactions.csv')
w= df21.iloc[:, 1]

df22= pd.read_csv('decreasing only below zero and stable only above zero reactions.csv')
x= df22.iloc[:, 1]

df23= pd.read_csv('increasing and decreasing and stable only above zero reactions.csv')
y= df23.iloc[:, 1]

df24= pd.read_csv('increasing and decreasing and stable only below zero reactions.csv')
z= df24.iloc[:, 1]

df25= pd.read_csv('decreasing and stable both positive and negative reactions.csv')
aa= df25.iloc[:, 1]

df26= pd.read_csv('increasing orand decreasing or both and stable below zero and decreasing above zero.csv')
ab= df26.iloc[:, 1]

df27= pd.read_csv('decreasing below zero and increasing or decreasing or both and stable above zero.csv')
ac= df27.iloc[:, 1]

df28= pd.read_csv('increasing and decreasing only above zero.csv')
ad= df28.iloc[:, 1]

df29= pd.read_csv('increasing and decreasing only below zero.csv')
ae= df29.iloc[:, 1]

df30= pd.read_csv('increasing and decreasing both positive and negative.csv')
af= df30.iloc[:, 1]

df31= pd.read_csv('one feasible value at zero reactions.csv')
ag= df31.iloc[:, 1]


intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))
intersect10 = pd.Series(np.intersect1d(b, l))
intersect11 = pd.Series(np.intersect1d(b, m))
intersect12 = pd.Series(np.intersect1d(b, n))
intersect13 = pd.Series(np.intersect1d(b, o))
intersect14 = pd.Series(np.intersect1d(b, p))
intersect15 = pd.Series(np.intersect1d(b, q))
intersect16 = pd.Series(np.intersect1d(b, r))
intersect17 = pd.Series(np.intersect1d(b, s))
intersect18 = pd.Series(np.intersect1d(b, t))
intersect19 = pd.Series(np.intersect1d(b, u))
intersect20 = pd.Series(np.intersect1d(b, v))
intersect21 = pd.Series(np.intersect1d(b, w))
intersect22 = pd.Series(np.intersect1d(b, x))
intersect23 = pd.Series(np.intersect1d(b, y))
intersect24 = pd.Series(np.intersect1d(b, z))
intersect25 = pd.Series(np.intersect1d(b, aa))
intersect26 = pd.Series(np.intersect1d(b, ab))
intersect27 = pd.Series(np.intersect1d(b, ac))
intersect28 = pd.Series(np.intersect1d(b, ad))
intersect29 = pd.Series(np.intersect1d(b, ae))
intersect30 = pd.Series(np.intersect1d(b, af))
intersect31 = pd.Series(np.intersect1d(b, ag))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-saturated only above zero original")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-flat only above zero original")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-flat only below zero original")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-flat both positive and negative original")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-saturated only below zero original")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-Ushaped_reactions only below zero original")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-saturated both positive and negative original")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-Ushaped both positive and negative original")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing and stable only above zero reactions original")
D9= pd.DataFrame(intersect10, columns=['Reaction names'])
D9.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing only above zero reactions original")
D10= pd.DataFrame(intersect11, columns=['Reaction names'])
D10.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and stable only below zero reactions original")
D11= pd.DataFrame(intersect12, columns=['Reaction names'])
D11.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing only below zero reactions original")
D12= pd.DataFrame(intersect13, columns=['Reaction names'])
D12.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-monotonically increasing and stable only above zero reactions original")
D13= pd.DataFrame(intersect14, columns=['Reaction names'])
D13.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-monotonically increasing only above zero reactions original")
D14= pd.DataFrame(intersect15, columns=['Reaction names'])
D14.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing and stable only below zero reactions original")
D15= pd.DataFrame(intersect16, columns=['Reaction names'])
D15.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing only below zero reactions original")
D16= pd.DataFrame(intersect17, columns=['Reaction names'])
D16.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing only below zero and increasing only above zero reactions original")
D17= pd.DataFrame(intersect18, columns=['Reaction names'])
D17.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing only below zero and decreasing only above zero reactions original")
D18= pd.DataFrame(intersect19, columns=['Reaction names'])
D18.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and stable only below zero and increasing only above zero reactions original")
D19= pd.DataFrame(intersect20, columns=['Reaction names'])
D19.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-stable only below zero and increasing only above zero reactions original")
D20= pd.DataFrame(intersect21, columns=['Reaction names'])
D20.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing only below zero and increasing and stable only above zero reactions original")
D21= pd.DataFrame(intersect22, columns=['Reaction names'])
D21.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing only below zero and stable only above zero reactions original")
D22= pd.DataFrame(intersect23, columns=['Reaction names'])
D22.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and decreasing and stable only above zero reactions original")
D23= pd.DataFrame(intersect24, columns=['Reaction names'])
D23.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and decreasing and stable only below zero reactions original")
D24= pd.DataFrame(intersect25, columns=['Reaction names'])
D24.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing and stable both positive and negative reactions original")
D25= pd.DataFrame(intersect26, columns=['Reaction names'])
D25.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing orand decreasing or both and stable below zero and decreasing above zero original")
D26= pd.DataFrame(intersect27, columns=['Reaction names'])
D26.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-decreasing below zero and increasing or decreasing or both and stable above zero original")
D27= pd.DataFrame(intersect28, columns=['Reaction names'])
D27.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and decreasing only above zero original")
D28= pd.DataFrame(intersect29, columns=['Reaction names'])
D28.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and decreasing only below zero original")
D29= pd.DataFrame(intersect30, columns=['Reaction names'])
D29.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-increasing and decreasing both positive and negative original")
D30= pd.DataFrame(intersect31, columns=['Reaction names'])
D30.to_csv("Common reactions stable below zero and decreasing and stable above zero lactose-one feasible value at zero original")
